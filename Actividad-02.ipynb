# %%
# Cálculo de autovalores y autovectores

import numpy as np

# Definimos la matriz
A = np.array([[5, 1],
              [2, 2]])

# Calculamos autovalores y autovectores
eigenvalues, eigenvectors = np.linalg.eig(A)

print("Autovalores:", eigenvalues)
print("Autovectores:\n", eigenvectors)
# Out:
# Autovalores: [5.56155281 1.43844719]
# Autovectores:
#  [[ 0.87192821 -0.27032301]
#  [ 0.48963374  0.96276969]]

# %%
# Realiza su autodescomposición y grafica los resultados obtenidos en un plano con Matplotlib.

import matplotlib.pyplot as plt

# Matriz A
A = np.array([[5, 1], [2, 2]])

# Autovalores y autovectores
eigenvalues, eigenvectors = np.linalg.eig(A)

# Origen para cada flecha
origin = np.zeros((2, eigenvectors.shape[1]))

# Crear figura
plt.figure(figsize=(6, 6))

# Graficar autovectores
plt.quiver(*origin, eigenvectors[0], eigenvectors[1],
           angles='xy', scale_units='xy', scale=1,
           color=['r', 'b'], label='Autovectores')

# Graficar transformación de la base estándar
x = np.array([[1, 0], [0, 1]])
transformed = A @ x.T
plt.quiver(*origin, transformed[0], transformed[1],
           angles='xy', scale_units='xy', scale=1,
           color=['g', 'purple'], alpha=0.5, label='Base transformada')

# Estética del gráfico
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.grid()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title("Autovectores y transformación de la base")
plt.gca().set_aspect('equal')
plt.legend()

# Guardar imagen
plt.savefig("autovectores_matriz_A.png", dpi=300)
plt.show()

# %%
# Genera dos vectores en R2 y represéntalos en un plano utilizando la librería Matplotlib.

import numpy as np
import matplotlib.pyplot as plt

# Vectores en R²
v1 = np.array([3, 4])
v2 = np.array([-2, 5])

# Graficar en el plano
plt.figure(figsize=(6, 6))
origin = np.array([[0, 0], [0, 0]])  # dos orígenes

# dibuja flechas desde el origen hacia las coordenadas de los vectores.
plt.quiver(*origin, [v1[0], v2[0]], [v1[1], v2[1]],
           angles='xy', scale_units='xy', scale=1,
           color=['r', 'b'])
# etiquetar cada vector directamente en el gráfico
plt.text(v1[0], v1[1], 'v1', color='r', fontsize=12)
plt.text(v2[0], v2[1], 'v2', color='b', fontsize=12)

plt.xlim(-5, 5)
plt.ylim(-5, 6)
plt.grid()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title("Vectores en $\mathbb{R}^2$")
plt.gca().set_aspect('equal')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np

a = np.array([3, 4])
b = np.array([-2, 5])

producto_punto = np.dot(a, b)
print("Producto punto:", producto_punto)
# Out:
# Producto punto: 14

# %%
import numpy as np

v1 = np.array([3, 4])
v2 = np.array([-2, 5])

norm_v1 = np.linalg.norm(v1)
norm_v2 = np.linalg.norm(v2)

print("Longitud de v1:", norm_v1)
print("Longitud de v2:", norm_v2)
# Out:
# Longitud de v1: 5.0
# Longitud de v2: 5.385164807134504

# %%
import numpy as np

v1 = np.array([3, 4])
v2 = np.array([-2, 5])

# Producto punto
dot_product = np.dot(v1, v2)

# Normas
norm_v1 = np.linalg.norm(v1)
norm_v2 = np.linalg.norm(v2)

# Ángulo en radianes
theta_rad = np.arccos(dot_product / (norm_v1 * norm_v2))

# Ángulo en grados
theta_deg = np.degrees(theta_rad)

print("Ángulo en radianes:", theta_rad)
print("Ángulo en grados:", theta_deg)
# Out:
# Ángulo en radianes: 1.0240074859056492
# Ángulo en grados: 58.67130713219583

# %%
v1 = np.array([3, 4])
v_ortogonal = np.array([-4, 3])

print("Vector ortogonal a v1:", v_ortogonal)
print("Producto punto:", np.dot(v1, v_ortogonal))  # Debe ser 0
# Out:
# Vector ortogonal a v1: [-4  3]
# Producto punto: 0

# %%
# Sea el vector base [-2, 7] que genera el subespacio unidimensional Encuentra: 
# El valor de la coordenada λ lambda

v_base = np.array([-2, 7])
x = np.array([-4, 14])

# Verificamos si x es múltiplo de v_base
lambda_val = x[0] / v_base[0]  # suponiendo v_base[0] ≠ 0

# Confirmamos con el segundo componente
if np.isclose(x[1], lambda_val * v_base[1]):
    print("λ =", lambda_val)
else:
    print("El vector no pertenece al subespacio generado por v_base.")
# Out:
# λ = 2.0

# %%
# Proyección ortogonal de un vector sobre un subespacio
# Supongamos que: u = [-2, 7] y x = [3, 1]


import numpy as np

u = np.array([-2, 7])
x = np.array([3, 1])

# Proyección ortogonal de x sobre el subespacio generado por u
projection = (np.dot(x, u) / np.dot(u, u)) * u
print("π_U(x) =", projection)

##############################################################################
# Visualización de la proyección ortogonal
import numpy as np
import matplotlib.pyplot as plt

# Vector base del subespacio
u = np.array([-2, 7])
# Vector a proyectar
x = np.array([3, 1])

# Cálculo de la proyección ortogonal
lambda_proj = np.dot(x, u) / np.dot(u, u)
projection = lambda_proj * u

# Graficamos
origin = np.array([[0, 0]])
fig, ax = plt.subplots()

# Vector original x
ax.quiver(*origin.T, x[0], x[1], angles='xy', scale_units='xy', scale=1, color='blue', label='x')

# Vector base u
ax.quiver(*origin.T, u[0], u[1], angles='xy', scale_units='xy', scale=1, color='green', label='u')

# Proyección π_U(x)
ax.quiver(*origin.T, projection[0], projection[1], angles='xy', scale_units='xy', scale=1, color='red', label='π_U(x)')

# Línea desde x hasta su proyección
ax.plot([x[0], projection[0]], [x[1], projection[1]], 'k--', linewidth=1)

# Configuración del gráfico
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 8)
ax.set_aspect('equal')
ax.grid(True)
ax.axhline(0, color='black', linewidth=0.5)
ax.axvline(0, color='black', linewidth=0.5)
ax.set_title("Proyección ortogonal de x sobre el subespacio generado por u")
ax.legend()
plt.show()
# Out:
# π_U(x) = [-0.03773585  0.13207547]

# %%
# matriz de proyección Pπ para proyectar por el subespacio

import numpy as np

u = np.array([-2, 7]).reshape(-1, 1)  # vector columna
x = np.array([3, 1]).reshape(-1, 1)

# Matriz de proyección
P_pi = (u @ u.T) / (u.T @ u)

# ahora encontramos la proyección del vector x sobre el vector u multiplicando la matriz de proyección por el vector x
projection = P_pi @ x

print("Matriz de proyección Pπ:\n", P_pi)
print("π_U(x):\n", projection.flatten())
# Out:
# Matriz de proyección Pπ:
#  [[ 0.0754717  -0.26415094]
#  [-0.26415094  0.9245283 ]]
# π_U(x):
#  [-0.03773585  0.13207547]

# %%
# Genera una matriz cuadrada con ( n > 3 ) y calcula su determinante y su traza.

import numpy as np

# Tamaño de la matriz (n > 3)
n = 4

# Generar matriz cuadrada aleatoria
A = np.random.randint(-10, 10, size=(n, n))
print("Matriz A:\n", A)

# Calcular determinante
det_A = np.linalg.det(A)
print("\nDeterminante de A:", det_A)

# Si el determinante es distinto de cero, la matriz es invertible, lo que implica que la transformación es reversible.
# El determinante permite saber si un sistema de ecuaciones tiene solución única (si es distinto de cero).

# Calcular traza (suma de la diagonal)
trace_A = np.trace(A)
print("Traza de A:", trace_A)
# Out:
# Matriz A:
#  [[ 8  4 -7 -3]
#  [ 5 -3  4  6]
#  [-1 -3  4  8]
#  [-3 -4 -4 -9]]
#
# Determinante de A: -2267.9999999999995
# Traza de A: 0

# %%
rango = np.linalg.matrix_rank(A)
print("Rango de A:", rango)
# Out:
# Rango de A: 4

# %%
# coeficientes del polinomio característico.
coeficientes = np.poly(A)
print("Coeficientes del polinomio característico:", coeficientes)
# Out:
# Coeficientes del polinomio característico: [ 1.00000000e+00 -1.02140518e-14 -5.30000000e+01 -7.28000000e+02
#  -2.26800000e+03]

# %%
# Raíces del polinomio característico

import numpy as np

coef = [1.0, -1.02140518e-14, -53.0, -728.0, -2268.0]
raices = np.roots(coef)

print("Raíces del polinomio:", raices)
# Out:
# Raíces del polinomio: [11.53822148+0.j         -3.81586338+5.97966899j -3.81586338-5.97966899j
#  -3.90649472+0.j        ]
